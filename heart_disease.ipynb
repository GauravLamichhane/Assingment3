# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading the CSV file

# %%
heart_data = pd.read_csv("heart_disease.csv")
heart_data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
heart_data.head(5)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
heart_data.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319789.000000   319778.000000  319781.000000  319576.000000
# mean       28.325348        3.371605       3.898384       7.096922
# std         6.356134        7.950662       7.955291       1.436165
# min        12.020000        0.000000       0.000000       1.000000
# 25%        24.030000        0.000000       0.000000       6.000000
# 50%        27.340000        0.000000       0.000000       7.000000
# 75%        31.420000        2.000000       3.000000       8.000000
# max        94.850000       30.000000      30.000000      24.000000

# %%
heart_data.describe(include='object')
# Out:
#        HeartDisease Smoking AlcoholDrinking  Stroke DiffWalking     Sex  \
# count        319795  319721          319680  319774      319762  319482
# unique            2       2               2       2           2       2
# top              No      No              No      No          No  Female
# freq         292422  187843          297908  307706      275363  167591
#
#        AgeCategory    Race Diabetic PhysicalActivity  GenHealth  Asthma  \
# count       319751  319756   319762           319779     319302  319795
# unique          13       6        4                2          5       2
# top          65-69   White       No              Yes  Very good      No
# freq         34143  245189   269626           247946     113657  276923
#
#        KidneyDisease SkinCancer
# count         319778     319795
# unique             2          2
# top               No         No
# freq          308001     289976

# %%
heart_data['HeartDisease'][0]
# Out:
# 'No'

# %%
heart_data['SkinCancer'][0]
# Out:
# 'Yes'

# %%
heart_data['PhysicalHealth'][0]
# Out:
# 3.0

# %%
heart_data['AlcoholDrinking'].value_counts()
# Out:
# AlcoholDrinking
# No     297908
# Yes     21772
# Name: count, dtype: int64

# %%
heart_data['Diabetic'].value_counts()
# Out:
# Diabetic
# No                         269626
# Yes                         40797
# No, borderline diabetes      6781
# Yes (during pregnancy)       2558
# Name: count, dtype: int64

# %%
heart_data.isna()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              False  False    False            False   False           False
# 1              False  False    False            False   False           False
# 2              False  False    False            False   False           False
# 3              False  False    False            False   False           False
# 4              False  False    False            False   False           False
# ...              ...    ...      ...              ...     ...             ...
# 319790         False  False    False            False   False           False
# 319791         False  False    False            False   False           False
# 319792         False  False    False            False   False           False
# 319793         False  False    False            False   False           False
# 319794         False  False    False            False   False           False
#
# ...

# %%
heart_data.isna().sum()
# Out:
# HeartDisease          0
# BMI                   6
# Smoking              74
# AlcoholDrinking     115
# Stroke               21
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease        17
# SkinCancer            0
# dtype: int64

# %%
heart_data['GenHealth_filled'] = heart_data['GenHealth'].fillna('ORCHID')

# %%
heart_data['GenHealth_filled'].isna().sum()
# Out:
# 0

# %%
heart_data[heart_data['GenHealth_filled']=='ORCHID']
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 252308           No  20.98      No              No     No             0.0
# 252309           No  21.63      No              No     No             3.0
# 252310          Yes  34.46      No              No     No             0.0
# 252311           No  26.54      No              No     No             0.0
# 252312           No  26.63      No              No     No             2.0
# ...             ...    ...     ...             ...    ...             ...
# 252796           No  21.95     Yes              No     No             0.0
# 252797           No  28.19     Yes              No     No            14.0
# 252798           No  32.55      No              No     No             0.0
# 252799           No  21.97     Yes              No     No             0.0
# 252800           No  28.13      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory  \
# ...

# %%
heart_data['GenHealth'] = heart_data['GenHealth'].replace({'ORCHID':'FAIR'})

# %%
heart_data[heart_data['GenHealth']=='ORCHID']
# Out:
# Empty DataFrame
# Columns: [HeartDisease, BMI, Smoking, AlcoholDrinking, Stroke, PhysicalHealth, MentalHealth, DiffWalking, Sex, AgeCategory, Race, Diabetic, PhysicalActivity, GenHealth, SleepTime, Asthma, KidneyDisease, SkinCancer, GenHealth_filled]
# Index: []

# %%
heart_data[heart_data['GenHealth_filled']=='FAIR']
# Out:
# Empty DataFrame
# Columns: [HeartDisease, BMI, Smoking, AlcoholDrinking, Stroke, PhysicalHealth, MentalHealth, DiffWalking, Sex, AgeCategory, Race, Diabetic, PhysicalActivity, GenHealth, SleepTime, Asthma, KidneyDisease, SkinCancer, GenHealth_filled]
# Index: []

# %%
heart_data['GenHealth_filled'] = heart_data['GenHealth_filled'].replace({'Fair':'NOT FAIR'})
heart_data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
scaler = LabelEncoder()
x = ['A','B','C']
x_scaled = scaler.fit_transform(x) # generates a unique value
print(x_scaled)
# Out:
# [0 1 2]

# %%
from sklearn.preprocessing import LabelEncoder
label_enc = LabelEncoder()
heart_data['DiffWalking_enc'] = label_enc.fit_transform(heart_data['DiffWalking'])
heart_data[['DiffWalking_enc','DiffWalking']]
# Out:
#         DiffWalking_enc DiffWalking
# 0                     0          No
# 1                     0          No
# 2                     0          No
# 3                     0          No
# 4                     1         Yes
# ...                 ...         ...
# 319790                1         Yes
# 319791                0          No
# 319792                0          No
# 319793                0          No
# 319794                0          No
#
# [319795 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_enc = LabelEncoder()
heart_data['smoking_enc'] = label_enc.fit_transform(heart_data['Smoking'])
heart_data[['smoking_enc','Smoking']]
# Out:
#         smoking_enc Smoking
# 0                 1     Yes
# 1                 0      No
# 2                 1     Yes
# 3                 0      No
# 4                 0      No
# ...             ...     ...
# 319790            1     Yes
# 319791            1     Yes
# 319792            0      No
# 319793            0      No
# 319794            0      No
#
# [319795 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_enc = LabelEncoder()
heart_data['Stroke_enc'] = label_enc.fit_transform(heart_data['Stroke'])
heart_data[['Stroke_enc','Stroke']]
# Out:
#         Stroke_enc Stroke
# 0                0     No
# 1                1    Yes
# 2                0     No
# 3                0     No
# 4                0     No
# ...            ...    ...
# 319790           0     No
# 319791           0     No
# 319792           0     No
# 319793           0     No
# 319794           0     No
#
# [319795 rows x 2 columns]

# %% [markdown]
# ###  Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('heart_disease.csv')

# %%
data.head(5)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
import numpy as np

# %%
x = range(20)
y = np.arange(50,70) + (np.random.random(20)*10)
plt.figure()
plt.scatter(x,y)
plt.title("Visualization")
plt.ylabel("value")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt  
heart_data = pd.read_csv('heart_disease.csv')
plt.figure()
plt.scatter(heart_data['BMI'], heart_data['SleepTime'])
plt.title("Scatter Plot of BMI vs. SleepTime")
plt.xlabel('BMI')
plt.ylabel('Sleep Time')
plt.show()
